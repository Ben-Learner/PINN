# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset


from collections import OrderedDict
from typing import List
from scipy.io import loadmat
from time import ctime

import seaborn as sns
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
matlab_data = loadmat("Project_IV_Data.mat")

u_bc_cases = matlab_data['u_bc']
u_data_cases = matlab_data['u_data']
v_data_cases = matlab_data['v_data']
x_2d = matlab_data['x_2d']
y_2d = matlab_data['y_2d']


u_bc_cases = torch.from_numpy(u_bc_cases).float().to(device)
u_data_cases = torch.from_numpy(u_data_cases).float().to(device)
v_data_cases = torch.from_numpy(v_data_cases).float().to(device)
x_2d = torch.from_numpy(x_2d).float().to(device)
y_2d = torch.from_numpy(y_2d).float().to(device)

# %%
class DNN(torch.nn.Module):
     # 构造函数，输入是各层的神经元数量
    def __init__(self, layers: List[int]):
        super().__init__()
        
        # 网络深度和激活函数，定义网络深度和激活函数
        self.depth = len(layers) + 1
        self.activation = torch.nn.Tanh

        # 有序字典储存网络的各层结构
        layer_list = list()
        for i in range(len(layers)-1): 
            layer_list.append(
                # 链接各层网络
                (f'layer_{i}', torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
        # 构建字典，字典中包含了layer层与层之间的连接信息
        layerDict = OrderedDict(layer_list)

        # 序列式构造神经网络，通过字典构建序列式神经网络
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x: torch.tensor):
        # 神经网络基于输入张量x而得到输出
        out = self.layers(x)
        return out

# %%
class DeepONet(nn.Module):

    def __init__(self, layer_size_branch, layer_size_trunk):
        super().__init__()

        # 主干网络和分支网络的结构，两个网络都嫁接于相同的DNN结构
        self.layer_size_branch = layer_size_branch
        self.layer_size_trunk = layer_size_trunk
        self.branch_net = DNN(self.layer_size_branch)
        self.trunk_net = DNN(self.layer_size_trunk)

        # 损失函数使用lambda定义
        self.loss_fun = lambda y_true, y_pred: torch.mean(torch.square(y_true - y_pred))

    def forward(self, x_branch, x_trunk):

        # 分支网络和主干网络分别做前向传播输出
        y_branch = self.branch_net(x_branch)
        y_trunk = self.trunk_net(x_trunk)
        
        # 主干网络和分支网络的输出进行内积 得到最终输出
        if y_branch.shape[-1] != y_trunk.shape[-1]:
            raise AssertionError(
                "Output sizes of branch net and trunk net do not match."
            )
        U = (y_branch[:, :5] * y_trunk[:, :5]).sum(dim=1, keepdim=True)  # 暂时没想好训练策略，试着同时训两个速度
        Y = (y_branch[:, 5:] * y_trunk[:, 5:]).sum(dim=1, keepdim=True)

        return torch.cat((U,Y), dim=1)

# %%
# 三元组数据集，分别为分支网络的输入（原函数在一些点的采样），主干网络的输入（变换函数的采样点坐标），和输出（变换函数的采样点结果
# 即： 边界函数的采样数据，内部流场的采样点坐标，内部流场的采样点速度
# 按照自己的理解，网络应该是可以预测个别点的速度的，所以主干网络的输入应该是具有灵活性，可以只输入一个点，而不是必须是整个流场的网格采样点的坐标
# 因此，主干网络的输入应该是两个节点，而分支网络的输入应该是完整的65个节点。
class TripleDataset(torch.utils.data.Dataset):
    
    def __init__(self, boundary_cases, coordiniates, velocity_field, device):
        self.device = device
        self.boundary_cases = torch.tensor(boundary_cases).float().to(self.device)   # 100*65
        self.coordiniates = torch.tensor(coordiniates).float().to(self.device)   # 65*65*2
        self.velocity_filed = torch.tensor(velocity_field).float().to(self.device)   # 100*65*65*2
    
    def __len__(self):
        return self.boundary_cases.shape[0] * self.coordiniates.shape[0] * self.coordiniates.shape[1]

    def __getitem__(self, index):
        case_index = index // (self.coordiniates.shape[0] * self.coordiniates.shape[1])
        x_index = (index % (self.coordiniates.shape[0] * self.coordiniates.shape[1])) // self.coordiniates.shape[1]
        y_index = (index % (self.coordiniates.shape[0] * self.coordiniates.shape[1])) % self.coordiniates.shape[1]
        return self.get(case_index, x_index, y_index)

    def get(self, case_index, x_index, y_index):
        return self.boundary_cases[case_index], self.coordiniates[x_index, y_index], self.velocity_filed[case_index, x_index, y_index]

    def getcase(self, single_case_index):
        case_index = torch.ones(self.coordiniates.shape[0] * self.coordiniates.shape[1], dtype=int) * single_case_index
        x_index = torch.arange(self.coordiniates.shape[0]).repeat(self.coordiniates.shape[1])
        y_index = torch.arange(self.coordiniates.shape[1]).repeat(self.coordiniates.shape[0])
        # x_index, y_index = torch.meshgrid(x_index, y_index)
        # print(case_index, x_index.shape, y_index.shape)
        return self.get(case_index, x_index, y_index)

# %%
# 只保留的源代码的主要功能部分
class Trainer(object):

    def __init__(self, model, device):
        self.model = model
        self.model.branch_net.to(device)
        self.model.trunk_net.to(device)
        self.device = device
        self.train_log = []
        self.trainloss_best = {"epoch": 0, "loss": 1e5}
        self.valloss_best = {"epoch": 0, "loss": 1e5}


class AdamTrainer(Trainer):

    def __init__(
        self, model: torch.nn.Module, learning_rate=1e-3
    ):
        super().__init__(model, device)
        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    def train_one_batch_adam(self, U_train_batch, X_train, S_train_batch):
        self.optimizer.zero_grad()
        preds = self.model(U_train_batch, X_train)
        loss = self.model.loss_fun(S_train_batch, preds)
        loss.backward()
        self.optimizer.step()
        
        return loss

    def train_adam(self, dataloader, num_epoch=10):
        for epoch in range(num_epoch):
            print("--------------------------------------------------------------")
            for batch, (boundary_cases, coordiniates, velocity_field) in enumerate(dataloader):
                loss = self.train_one_batch_adam(boundary_cases, coordiniates, velocity_field)
                print(f"Epoch :{epoch:<6d} Batch: {batch:<6d} train loss: {loss:.3f}")
            self.train_log.append([epoch, batch, loss.cpu().detach().numpy()])

# %%
# 分支网络和主干网络的结构
# 分支网络接受函数，即边界条件的采样点结果， 65个点的水平速度
# 主干网络接受坐标，即变换函数的采样点坐标， 任意一个点的x，y坐标
# 输出为变换函数的采样点结果
onet = DeepONet([65, 10, 10], [2, 10, 10])

coordiniates = torch.stack((x_2d, y_2d), dim=2)
velocity_field = torch.stack((u_data_cases, v_data_cases), dim=3)

dataset = TripleDataset(boundary_cases=u_bc_cases,  # 100个case的边界条件
                coordiniates=coordiniates,  # 65*65个点的坐标
                velocity_field=velocity_field, # 100个case的65*65个点的速度
                device=device)

dataloader = DataLoader(dataset, batch_size=1024, shuffle=True)
trainer = AdamTrainer(onet)
trainer.train_adam(dataloader, num_epoch=1)
# case_index, x_index, y_index = 10, 4, 5
# boundary_cases, coordiniates, velocity_field = dataset.get(case_index, x_index, y_index)
# Out:
# /var/folders/3j/332tsm6940n1fm80jlfl_dx40000gn/T/ipykernel_4989/3597938053.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.boundary_cases = torch.tensor(boundary_cases).float().to(self.device)   # 100*65
# /var/folders/3j/332tsm6940n1fm80jlfl_dx40000gn/T/ipykernel_4989/3597938053.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.coordiniates = torch.tensor(coordiniates).float().to(self.device)   # 65*65*2
# /var/folders/3j/332tsm6940n1fm80jlfl_dx40000gn/T/ipykernel_4989/3597938053.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.velocity_filed = torch.tensor(velocity_field).float().to(self.device)   # 100*65*65*2
# --------------------------------------------------------------
# Epoch :0      Batch: 0      train loss: 0.043
# Epoch :0      Batch: 1      train loss: 0.043
# Epoch :0      Batch: 2      train loss: 0.035
# Epoch :0      Batch: 3      train loss: 0.035
# Epoch :0      Batch: 4      train loss: 0.035
# Epoch :0      Batch: 5      train loss: 0.039
# Epoch :0      Batch: 6      train loss: 0.037
# Epoch :0      Batch: 7      train loss: 0.033
# Epoch :0      Batch: 8      train loss: 0.036
# Epoch :0      Batch: 9      train loss: 0.036
# Epoch :0      Batch: 10     train loss: 0.034
# Epoch :0      Batch: 11     train loss: 0.036
# Epoch :0      Batch: 12     train loss: 0.031
# Epoch :0      Batch: 13     train loss: 0.033
# Epoch :0      Batch: 14     train loss: 0.034
# Epoch :0      Batch: 15     train loss: 0.032
# Epoch :0      Batch: 16     train loss: 0.031
# Epoch :0      Batch: 17     train loss: 0.032
# Epoch :0      Batch: 18     train loss: 0.033
# Epoch :0      Batch: 19     train loss: 0.032
# Epoch :0      Batch: 20     train loss: 0.033
# Epoch :0      Batch: 21     train loss: 0.031
# Epoch :0      Batch: 22     train loss: 0.032
# Epoch :0      Batch: 23     train loss: 0.032
# Epoch :0      Batch: 24     train loss: 0.033
# Epoch :0      Batch: 25     train loss: 0.028
# Epoch :0      Batch: 26     train loss: 0.032
# Epoch :0      Batch: 27     train loss: 0.031
# Epoch :0      Batch: 28     train loss: 0.032
# Epoch :0      Batch: 29     train loss: 0.028
# Epoch :0      Batch: 30     train loss: 0.030
# Epoch :0      Batch: 31     train loss: 0.030
# Epoch :0      Batch: 32     train loss: 0.027
# Epoch :0      Batch: 33     train loss: 0.029
# Epoch :0      Batch: 34     train loss: 0.032
# Epoch :0      Batch: 35     train loss: 0.027
# Epoch :0      Batch: 36     train loss: 0.027
# Epoch :0      Batch: 37     train loss: 0.030
# Epoch :0      Batch: 38     train loss: 0.028
# Epoch :0      Batch: 39     train loss: 0.025
# Epoch :0      Batch: 40     train loss: 0.024
# Epoch :0      Batch: 41     train loss: 0.027
# Epoch :0      Batch: 42     train loss: 0.027
# Epoch :0      Batch: 43     train loss: 0.023
# Epoch :0      Batch: 44     train loss: 0.024
# Epoch :0      Batch: 45     train loss: 0.027
# Epoch :0      Batch: 46     train loss: 0.025
# Epoch :0      Batch: 47     train loss: 0.025
# Epoch :0      Batch: 48     train loss: 0.023
# Epoch :0      Batch: 49     train loss: 0.025
# Epoch :0      Batch: 50     train loss: 0.027
# Epoch :0      Batch: 51     train loss: 0.028
# Epoch :0      Batch: 52     train loss: 0.025
# Epoch :0      Batch: 53     train loss: 0.024
# Epoch :0      Batch: 54     train loss: 0.027
# Epoch :0      Batch: 55     train loss: 0.027
# Epoch :0      Batch: 56     train loss: 0.025
# Epoch :0      Batch: 57     train loss: 0.022
# Epoch :0      Batch: 58     train loss: 0.026
# Epoch :0      Batch: 59     train loss: 0.023
# Epoch :0      Batch: 60     train loss: 0.022
# Epoch :0      Batch: 61     train loss: 0.022
# Epoch :0      Batch: 62     train loss: 0.024
# Epoch :0      Batch: 63     train loss: 0.023
# Epoch :0      Batch: 64     train loss: 0.021
# Epoch :0      Batch: 65     train loss: 0.023
# Epoch :0      Batch: 66     train loss: 0.021
# Epoch :0      Batch: 67     train loss: 0.023
# Epoch :0      Batch: 68     train loss: 0.021
# Epoch :0      Batch: 69     train loss: 0.020
# Epoch :0      Batch: 70     train loss: 0.021
# Epoch :0      Batch: 71     train loss: 0.024
# Epoch :0      Batch: 72     train loss: 0.021
# Epoch :0      Batch: 73     train loss: 0.021
# Epoch :0      Batch: 74     train loss: 0.020
# Epoch :0      Batch: 75     train loss: 0.019
# Epoch :0      Batch: 76     train loss: 0.021
# Epoch :0      Batch: 77     train loss: 0.020
# Epoch :0      Batch: 78     train loss: 0.022
# Epoch :0      Batch: 79     train loss: 0.022
# Epoch :0      Batch: 80     train loss: 0.019
# Epoch :0      Batch: 81     train loss: 0.023
# Epoch :0      Batch: 82     train loss: 0.020
# Epoch :0      Batch: 83     train loss: 0.022
# Epoch :0      Batch: 84     train loss: 0.020
# Epoch :0      Batch: 85     train loss: 0.019
# Epoch :0      Batch: 86     train loss: 0.020
# Epoch :0      Batch: 87     train loss: 0.021
# Epoch :0      Batch: 88     train loss: 0.018
# Epoch :0      Batch: 89     train loss: 0.020
# Epoch :0      Batch: 90     train loss: 0.020
# Epoch :0      Batch: 91     train loss: 0.020
# Epoch :0      Batch: 92     train loss: 0.020
# Epoch :0      Batch: 93     train loss: 0.020
# Epoch :0      Batch: 94     train loss: 0.022
# Epoch :0      Batch: 95     train loss: 0.018
# Epoch :0      Batch: 96     train loss: 0.019
# Epoch :0      Batch: 97     train loss: 0.020
# Epoch :0      Batch: 98     train loss: 0.020
# Epoch :0      Batch: 99     train loss: 0.018
# Epoch :0      Batch: 100    train loss: 0.018
# Epoch :0      Batch: 101    train loss: 0.018
# Epoch :0      Batch: 102    train loss: 0.018
# Epoch :0      Batch: 103    train loss: 0.019
# Epoch :0      Batch: 104    train loss: 0.018
# Epoch :0      Batch: 105    train loss: 0.020
# Epoch :0      Batch: 106    train loss: 0.019
# Epoch :0      Batch: 107    train loss: 0.019
# Epoch :0      Batch: 108    train loss: 0.018
# Epoch :0      Batch: 358    train loss: 0.017
# Epoch :0      Batch: 359    train loss: 0.018
# Epoch :0      Batch: 360    train loss: 0.019
# Epoch :0      Batch: 361    train loss: 0.017
# Epoch :0      Batch: 362    train loss: 0.017
# Epoch :0      Batch: 363    train loss: 0.017
# Epoch :0      Batch: 364    train loss: 0.017
# Epoch :0      Batch: 365    train loss: 0.017
# Epoch :0      Batch: 366    train loss: 0.018
# Epoch :0      Batch: 367    train loss: 0.017
# Epoch :0      Batch: 368    train loss: 0.019
# Epoch :0      Batch: 369    train loss: 0.019
# Epoch :0      Batch: 370    train loss: 0.017
# Epoch :0      Batch: 371    train loss: 0.017
# Epoch :0      Batch: 372    train loss: 0.018
# Epoch :0      Batch: 373    train loss: 0.018
# Epoch :0      Batch: 374    train loss: 0.017
# Epoch :0      Batch: 375    train loss: 0.018
# Epoch :0      Batch: 376    train loss: 0.017
# Epoch :0      Batch: 377    train loss: 0.017
# Epoch :0      Batch: 378    train loss: 0.019
# Epoch :0      Batch: 379    train loss: 0.017
# Epoch :0      Batch: 380    train loss: 0.018
# Epoch :0      Batch: 381    train loss: 0.016
# Epoch :0      Batch: 382    train loss: 0.017
# Epoch :0      Batch: 383    train loss: 0.017
# Epoch :0      Batch: 384    train loss: 0.018
# Epoch :0      Batch: 385    train loss: 0.020
# Epoch :0      Batch: 386    train loss: 0.019
# Epoch :0      Batch: 387    train loss: 0.017
# Epoch :0      Batch: 388    train loss: 0.018
# Epoch :0      Batch: 389    train loss: 0.018
# Epoch :0      Batch: 390    train loss: 0.020
# Epoch :0      Batch: 391    train loss: 0.017
# Epoch :0      Batch: 392    train loss: 0.017
# Epoch :0      Batch: 393    train loss: 0.017
# Epoch :0      Batch: 394    train loss: 0.017
# Epoch :0      Batch: 395    train loss: 0.017
# Epoch :0      Batch: 396    train loss: 0.017
# Epoch :0      Batch: 397    train loss: 0.018
# Epoch :0      Batch: 398    train loss: 0.017
# Epoch :0      Batch: 399    train loss: 0.016
# Epoch :0      Batch: 400    train loss: 0.016
# Epoch :0      Batch: 401    train loss: 0.016
# Epoch :0      Batch: 402    train loss: 0.018
# Epoch :0      Batch: 403    train loss: 0.019
# Epoch :0      Batch: 404    train loss: 0.017
# Epoch :0      Batch: 405    train loss: 0.017
# Epoch :0      Batch: 406    train loss: 0.017
# Epoch :0      Batch: 407    train loss: 0.017
# Epoch :0      Batch: 408    train loss: 0.018
# Epoch :0      Batch: 409    train loss: 0.017
# Epoch :0      Batch: 410    train loss: 0.018
# Epoch :0      Batch: 411    train loss: 0.019
# Epoch :0      Batch: 412    train loss: 0.018

# %%
boundary_cases, coordiniates, velocity_field = dataset.getcase(0)
preds = trainer.model(boundary_cases, coordiniates)
plt.imshow(preds.cpu().detach().numpy().reshape(65,65,2)[:,:,0])

# %%
plt.imshow(velocity_field.cpu().detach().numpy().reshape(65,65,2)[:,:,0])

# %%
loss = np.array(trainer.train_log)[:, 2]
plt.plot(loss)
